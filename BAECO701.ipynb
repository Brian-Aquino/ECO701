# %% [markdown]
#    <h2 style="text-align:center"><font face="Times New Roman">Assignment#1</font></h2>
#                                                           <h3 style="text-align:right">Brian Aquino</h3>
# <font face="Times New Roman" size="2">
# <h3>1.
# </h3></font>
# <br>
# <br>
# <br>
# <br>
# <p><font face="Times New Roman" size="5">I)
# </font></p>
#
# <h2>
# \begin{equation*}
# U(x,y)= xy
# \end{equation*}
# \begin{equation*}
# f_x =MU_x= \frac{\partial U}{\partial x} =y,
# \ f_y =MU_y= \frac{\partial U}{\partial y} =x \\
# U(x,y)= x^1y^1  \ \ where \ \ \frac{\alpha}{\alpha + \beta} \ + \frac{\beta}{\alpha + \beta}= 1 \\
# \frac{1}{1 + 1} \ + \frac{1}{1 + 1}= 1
# \end{equation*}
# </h2>
#
# <p style="text-align:left"></p>

# %% [markdown]
# <p><font face="Times New Roman" size="5">II)
# </font></p>
# <h2>
# \begin{equation*}
# P_xx + P_yy= M \\
#  x(20,40,800),
# \ y(20,40,800)
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5">The slope of the budget line is:
# \begin{equation*}
# -\frac{P_x}{P_y}= -\frac{20}{40}= \left\lvert -\frac{1}{2} \right\rvert
# \\
# P_y=2P_x
# \end{equation*}
# </font>
# </p>
#
#
#
# <p><font face="Times New Roman" size="5">In other words, the price of clothing is twice as much as food.</font></p>

# %%
import __future__
from __future__ import division
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact, fixed

# %%
def U(c1, c2, alpha):
    return (c1**alpha)*(c2**(1-alpha))

def budgetc(c1, p1, p2, I):
    return (I/p2)-(p1/p2)*c1

def indif(c1, ubar, alpha):
    return (ubar/(c1**alpha))**(1/(1-alpha))

# %%
def find_opt(p1,p2,I,alpha):
    c1 = alpha * I/p1
    c2 = (1-alpha)*I/p2
    u = U(c1,c2,alpha)
    return c1, c2, u

# %%
alpha = 0.5
p1, p2 = 1, 2
I = 800

# %%
2/3
# Out:
# 0.6666666666666666

# %%
# this is just for axis limits
pmin, pmax = 1, 4
Imin, Imax = 10, 200
cmax = (3/4)*Imax/pmin
cmax=1000

# %%
c1 = np.linspace(0.1,cmax,num=100)
budgetc(50, p1,p2,1000)
# Out:
# 475.0

# %%
def consume_plot(p1=p1, p2=p2, I=I, alpha=alpha):

    c1 = np.linspace(0.1,cmax,num=100)
    c1e, c2e, uebar = find_opt(p1, p2 ,I, alpha)
    idfc = indif(c1, uebar, alpha)
    budg = budgetc(c1, p1, p2, I)

    fig, ax = plt.subplots(figsize=(8,8))
    ax.plot(c1, budg, lw=2.5)
    ax.plot(c1, idfc, lw=2.5)
    ax.vlines(c1e,0,c2e, linestyles="dashed")
    ax.hlines(c2e,0,c1e, linestyles="dashed")
    ax.plot(c1e,c2e,'ob')
    ax.set_xlim(0, cmax)
    ax.set_ylim(0, cmax)
    ax.set_xlabel(r'$c_1$', fontsize="20")
    ax.set_ylabel('$c_2$', fontsize="20")
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.tick_params(labelsize="20")
    ax.grid()
    plt.show()

# %%
p1,p2
# Out:
# (1, 2)

# %%
consume_plot(p1, p2, 800, 0.5)

# %% [markdown]
# <p><font face="Times New Roman" size="5">III)
# </font></p>
#
# <h2 style="text-align:left">
# MRS:
# \begin{equation*}
# \frac{f_x}{f_y} = \frac{y}{x}
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5"> The MRS is measured by the rate at which one good is exchanged for another, while maintaining the same level of utility (on the same indifference curve)
# </font></p>

# %% [markdown]
# <p><font face="Times New Roman" size="5">IV)
# </font></p><h1 style="text-align:center"><font face="Times New Roman">Tangency Method</font></h1>
# <h2 style="text-align:left">
# \begin{equation*}
# \frac{y}{x}= \frac{P_x}{P_y} \Rightarrow \ P_yy = P_xx \\
# P_xx+ P_xx = M \Rightarrow \ 2P_xx=M \Rightarrow x= \frac{M}{2P_x} \Rightarrow  \ x= \frac{800}{2(40)}
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5"> Similarly, we can do the same for y.
# </font></p>
# <h2>
# \begin{equation*}
# P_yy+ P_yy = M \Rightarrow \ 2P_yy=M \Rightarrow y= \frac{M}{2P_y} \Rightarrow \ y= \frac{800}{2(20)}
#   \\  x \ = \ 20, \ y \ = 10
# \end{equation*}
# </h2>
# </font></p><h1 style="text-align:center"><font face="Times New Roman">Substitution Method</font></h1>
#
# <p><font face="Times New Roman" size="5">Making x and y a function of price and income results in the same equation shown above:</font></p>
# <h2>
# \begin{equation*}
# P_yy+ P_yy = M \Rightarrow \ 2P_yy=M \rightarrow y= \frac{M}{2P_y} \Rightarrow \ y= \frac{800}{2(20)}
#    \\ x \ = \ 20, \ y \ = 10
# \end{equation*}
# </h2>
# <<h1 style="text-align:center"><font face="Times New Roman">Method of Lagrange</font></h1>
# <h2>
# \begin{equation*}
# g(x,y)= 20x +40y= 800  \rightarrow \ x+2y=40   \ \  \ \ \ \ \ u(x,y)=xy \ \ \ \ \ g(x,y)=x+2y-40 \\
# \mathcal{L} = u(x,y) + \lambda (x+2y-40) \\
# \mathcal{L} = xy + \lambda (x+2y-40) \\
# \frac{\partial \mathcal{L}}{\partial x}= y+ \lambda \ \ \ \  \frac{\partial \mathcal{L}}{\partial y}= x+2 \lambda \ \ \
# \frac{\partial \mathcal{L}}{\partial \lambda}=x+2y-40 \\
# let  \ \ \frac{\partial \mathcal{L}}{\partial x} = 0, \ \ y+ \lambda =0 \rightarrow y=- \lambda \ \ \ \\
# let  \ \ \frac{\partial \mathcal{L}}{\partial y} = 0, \ \ x+ 2 \lambda =0 \rightarrow x=-2 \lambda  \\
# let  \ \ \frac{\partial \mathcal{L}}{\partial \lambda} = 0, \ \ x+2y-40 =0
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5">Now substitute the values of x and y into the equation below to solve for x and y:
# <br>
# \begin{equation*}
#  \ \ \ \ \ x+2y-40=0 \\
# 	\downarrow \\
# -2 \lambda + -2 \lambda =40 \\
#  \ \ \ \ \downarrow \\
#  \frac{-4 \lambda}{-4}= \frac{40}{-4}, \ \ \lambda=-10  \\
#  \ \ \ \ \ \ \ \ \ \ \ \swarrow \searrow \\
#  \ \ \ y= \left\lvert - \lambda \right\rvert \ x= \left\lvert - \lambda \right\rvert \\
#  Therefore, \ x=20, \ y=10
#  \end{equation*}  </font></p>
# <br>
# <br>
# <p><font face="Times New Roman" size="5">The lagrange multiplier optimizes a function given a consumer's budget constraint. In this problem, it is the amount of utility gained from an additional dollar in the budget constraint. The first constraint (budget) is the amount of utility gained from an additional dollar in the budget. The second constraint is the amount of utility gained from an increase in tonnage.  </font></p>
# <br>
# <p><font face="Times New Roman" size="5">V)
# </font></p>
# <br>
# <p><font face="Times New Roman" size="5">
#
# In the previous problem I have expressed Luz's consumer demands as a function of any income and prices. </font></p>

# %% [markdown]
# <p><font face="Times New Roman" size="5">VI)
# </font></p>
# <h2>
# \begin{equation*}
# u(x,y)=  \ \frac{\alpha}{\alpha + \beta} \ \frac{I}{P_x} \ \times \frac{\beta}{\alpha + \beta} \frac{I}{P_y}  \\
# \\ \\ \\ \\ u(x,y)=20*10 =200
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5"> The value of maximized utility at an optimum is 200. There is a monotonic  transformation. Although the consumer has the same preference, their utility has changed. For this reason, their lagrange multiplier has not changed.</font></p>
# <br>
# <br>
# <p><font face="Times New Roman" size="5">VII)
# </font></p>
# <p><font face="Times New Roman" size="5"> We can see this by using the langragian method</font></p>
#
# <h2>
# \begin{equation*}
# \mathcal{L}=x^.5y^.5  \\
# \mathcal{L}= x^.5y^.5 + \lambda(x+2y-40) \\
# \\ solve \ \ for \  \ \lambda, \
# \frac{\partial \mathcal{L}}{\partial x}=\frac{y^.5}{2x^.5}+ \lambda=0 \rightarrow \ - \lambda= \frac{y^.5}{2x^.5} \\
# \frac{\partial \mathcal{L}}{\partial y}=\frac{x^.5}{2y^.5} +2 \lambda=0 \rightarrow \ - \lambda= \frac{x^.5}{4y^.5} \\
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5">We can now set both negative lambdas equal to one another to solve for one of the variables:</font></p>
# <h2>
# \begin{equation*}
# \frac{y^.5}{2x^.5} =   \frac{x^.5}{4y^.5}  \rightarrow \ 2y=x \\
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5">Substitute x for y: </font></p>
# <h2>
# \begin{equation*}
# \frac{\partial \mathcal{L}}{\partial \lambda}, \ when \ \frac{\partial \mathcal{L}}{\partial \lambda}=0
# \\ x+2y-40=0 \Rightarrow \ 2y+2y-40 \\
# \\\frac{4y}{4}= \frac{40}{4}, \ y=10 \
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5">Similarly, we solve for x </font></p>
# <h2>
# \begin{equation*}
# x+2(10)-40=0 \ , x=20
# \end{equation*}
# </h2>

# %% [markdown]
# <h3><font face="Times New Roman" size="5">2.
# </font>
# <br>
# <br>
# <br>
# <br>
# I)
# </h3>
# <h2>
# \begin{equation*}
#  \underset{x,y}{min}  \ \ P_xx+P_yy,                   \ \ \  U(x,y)= \overline{U},    \ \ \ f(x)=0=xy- \overline{u}\\
# \mathcal{L}=P_xx+P_yy[xy-y- \overline{u} ]  \\
# \frac{\partial \mathcal{L}}{\partial x}=P_x+ \lambda y=0  \ \ \ \rightarrow   \ \  \ \frac{P_x}{y}=  - \lambda \\
# \frac{\partial \mathcal{L}}{\partial y}=P_y + \lambda y=0  \ \ \rightarrow  \ \ \ \frac{P_y}{x}=  - \lambda , \ \ \ \
# \frac{\partial \mathcal{L}}{\partial \lambda}=xy- \overline{u} \\
# y= \frac{P_xx}{P_y}, \ \  x= \frac{P_yy}{P_x} \\
# \frac{P_xx}{Px}= \frac{P_yy}{P_x} \\
#  0= \frac{\partial \mathcal{L}}{\partial \lambda}=x \frac{P_xx}{P_y}- \overline{u} \rightarrow \frac{P_xx^2}{P_y}= \overline{u} \\ x^2= \frac{P_y \overline{u}}{P_x} \Rightarrow \ x= \sqrt{\frac{P_y \overline{u}}{P_x}} \ \ \  Similarly: y= \sqrt{\frac{P_x \overline{u}}{P_y}}
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5">II)
# </font></p>
# <br>
# <p><font face="Times New Roman" size="5">Since the lagrange multiplier isn't changing (rate of change of optimal output) and the price ratio is the same on the same budget line, the optimal bundle does not change</font></p>

# %% [markdown]
# <h3><font face="Times New Roman" size="5">3)
# <br>
# <br>
# </font></h3>
# <p><font face="Times New Roman" size="5">I)
# </font></p>
# <h2>
# \begin{equation*}
# 1000x+2000y=100,000   \ \ P_x=1, \ P_y=2, \ \  \ \ M=100,\ \  U(x,y)=x_fy_w \\ \ \ \  \ \
# \ \ \  \  Budget \ \ constraint: \ \ \frac{1000x}{1000}+ \frac{2000y}{1000}= \frac{100,000}{1000} \ \ \Rightarrow  \ x+2y=100 \\
# \ \ \ \  Tonnage \ \ contraint:  \ \ x +y=80 \\
# \mathcal{L} =xy+ \lambda [x+2y-100]+ \mu[x+y-80] \\
# 0= \frac{\partial \mathcal{L}}{\partial \mu}=x+y-80,  \\ \ 0= \frac{\partial \mathcal{L}}{\partial x}=y+ \lambda + \mu,\ 0=\frac{\partial \mathcal{L}}{\partial y} =x+2 \lambda + \mu,\ 0= \frac{\partial \mathcal{L}}{\partial \lambda}=x+2y=100 \\
# \begin{array}{rcl}-x & = & - \lambda - \mu \\ y & = & 2 \lambda + x \end{array} \\
# -------- \\
# y-x= \lambda \\
# \Downarrow \\
# \frac{\partial \mathcal{L}}{\partial x}=y+(y-x)+ \mu \ \Rightarrow \ 2y-x+ \mu =0  \Rightarrow \ \mu=-2y+x
# \end{equation*}
# </h2>
# <h2><bold>*Figure out interpretation of lagrange multiplier in this case</bold></h2>
#
# <p><font face="Times New Roman" size="5">II)  &  III)
# Conditions of the restraints:
# </font></p>
# <h2>
# \begin{equation*}
# \mu >0,\  \lambda =0  \ \ \ \ Tonnage \ \ constraint \ \ \rightarrow x= \frac{T}{2}, y= \frac{T}{2}  \\
# \mu =0, \ \lambda >0 \ \ \ Budget  \ \ constraint  \ \rightarrow  x= \frac{I}{2P_x}, y= \frac{I}{2P_y}
# \end{equation*}
# </h2>
# <h3 style="text-align:center"><font size="5">Optimal Bundle When There's Tonnage Constraint:</font></h3>
# <h2>
# \begin{equation*}
# x= \frac{80}{2}=40,  \ y= \frac{80}{2}=40,  \
# U(x,y)=40*40=1600
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="4">This solution is not feasible.</font></p>
# <h3 style="text-align:center"><font size="5">Optimal Bundle When There's Budget Constraint:</font></h3>
# <h2>
# \begin{equation*}
# x= \frac{100}{2}=50, \ y= \frac{100}{4}=25, \ U(x,y)=50*25=1250
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="4">This solution is feasible and provides the highest utility. Therefore, when budget is slack and tonnage is constrained is when this individual will receive the maximum amount of utility </font></p>
# <br>
# <p><font face="Times New Roman" size="5">Answer: </font></p>
# <h2>
# \begin{equation*}
# \mu >0 , \lambda =0
# \end{equation*}
# </h2>
# <h3 style="text-align:center"><font size="5">Optimal Bundle When There's Budget and Tonnage Constraint</font></h3>
# <h2>
# \begin{equation*}
# \mu > 0 (binding), \ \lambda>0(binding) \\
# \begin{array}{rcl}100000 & = & 1000x + 2000y \\ 80000 & = & -1000x -1000y \end{array} \\
# ------------- \\
# \frac{1000y}{1000}= \frac{20000}{10000} \\ \downarrow
# \\ y=20 \rightarrow
# x+y=80 \rightarrow x+20=80 \\
# x=60 \\
# U(x,y)=20*60=1200
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="4">This solution is also feasible, but does not provide the highest utility. </font></p>

# %%
import matplotlib.lines as mlines
from matplotlib.legend_handler import HandlerLine2D
import matplotlib.pyplot as plt
#plt.style.available
plt.style.use("bmh")
# %matplotlib inline

# %%
x= np.linspace(0,100, 30)
def tonnage(x):
    return 80-x


def budgl(x):
    return (100/2)-(1/2)*x

# %%
budgl(x)
# Out:
# array([ 50.        ,  48.27586207,  46.55172414,  44.82758621,
#         43.10344828,  41.37931034,  39.65517241,  37.93103448,
#         36.20689655,  34.48275862,  32.75862069,  31.03448276,
#         29.31034483,  27.5862069 ,  25.86206897,  24.13793103,
#         22.4137931 ,  20.68965517,  18.96551724,  17.24137931,
#         15.51724138,  13.79310345,  12.06896552,  10.34482759,
#          8.62068966,   6.89655172,   5.17241379,   3.44827586,
#          1.72413793,   0.        ])

# %%
plt.figure(figsize=(6,6))
plt.plot(x,tonnage(x), color="blue")
plt.plot(x,budgl(x), color="red")
plt.xlim(0,100)
plt.ylim(0,100)
plt.fill_between(x, np.minimum((tonnage(x)),(budgl(x))), color="gray")
plt.scatter(50,25,s=50,color="black")
plt.scatter(40,40,s=50,color="red")
plt.scatter(60,20,s=50,color="black")
plt.xlabel("x",fontsize="20")
plt.ylabel("y",fontsize="20")
line1, = plt.plot([3,2,1], label='Tonnage Constraint', color="blue")
line2, = plt.plot([1,2,3], label='Budget Constraint',color="red")
plt.tick_params(labelsize="20")
plt.legend(handler_map={line1: HandlerLine2D()})
plt.show()

# %% [markdown]
# <p><font face="Times New Roman" size="5">4)
# </font></p>
#
# <br>
# <br>
# <p><font face="Times New Roman" size="5">I)
# </font></p>

# %%
cmax =1000
x = np.linspace(0.1,10, 400)
x2 = np.linspace(0.1, np.sqrt(199.99),800)
def ppf(x,Ax):
    return np.sqrt(100-(x**2/Ax))

# %%
plt.style.use("seaborn-white")
plt.figure(figsize=(6,6))
plt.plot(x, ppf(x,1), color="red")
plt.xlabel("Coconuts", fontsize="20")
plt.ylabel("Fish", fontsize="20")
plt.text(6.5,8,r"MRT=$\mathdefault{\frac{dy}{dy}= - \frac{x}{y}}$", fontsize=18)
plt.tick_params(labelsize="20")
plt.show()

# %% [markdown]
# <p><font face="Times New Roman" size="5">II)
# </font></p>
# <br>
# <br>
# <h2>
# \begin{equation*}
# L_x+L_y= \overline{L}, \ \ \ \ \\ \frac{x^2}{A_x}+y^2=100, \ \ \ U(x,y)=ax+by \
# \\ f(x)= \frac{x^2}{A_x}+y^2=100 \ \ \ \ when \ A_x=1 \\
# f^1(x)=2xdx+2ydy=0 \ \Rightarrow \ 2xdx=-2ydy \ \rightarrow \ \frac{dy}{dx}= - \frac{x}{y}= MRT
# \end{equation*}
# </h2>
# <br>
# <p><font face="Times New Roman" size="5">III)
# </font></p>
# <h2>
# \begin{equation*}
# \mathcal{L}= U(x,y)+ \lambda [g(x)] \\
# \mathcal{L}=ax+by +\lambda [x^2+y^2-100] \\
# 0= \frac{\partial \mathcal{L}}{\partial x}=a+2 \lambda x, \ 0= \frac{\partial \mathcal{L}}{\partial y}=b+2 \lambda y, \ 0= \frac{\partial \mathcal{L}}{\partial \lambda}=x^2+y^2-100 \\
# 0= \frac{\partial \mathcal{L}}{\partial x}=a+2 \lambda \rightarrow \ \lambda = - \frac{a}{2x}, \ 0= \frac{\partial \mathcal{L}}{\partial y}=b+2 \rightarrow \lambda = - \frac{b}{2y} \\
# - \frac{a}{2x}= - \frac{b}{2y} \\
# \downarrow \\
# \frac{\partial \mathcal{L}}{\partial \lambda}=x^2+y^2-100 \\
# \Rightarrow \left(\frac{ya}{b}\right)^2+y^2-100 \\
# \Rightarrow \frac{y^2a^2}{b^2}+y^2-100 \\
# \Rightarrow y^2 \left(\frac{a^2+1}{b^2}\right) =100 \\
# \Rightarrow y^2 \left(\frac{a^2+b^2}{b^2}\right) =100
# \Rightarrow y^2 \frac{\left(\frac{a^2+b^2}{b^2}\right)}{\left(\frac{a^2+b^2}{b^2}\right)} = \frac{100}{\left(\frac{a^2+b^2}{b^2}\right)} \\
# \Rightarrow \ \left(y^2\right)^.5= \left(\frac{100b^2}{a^2+b^2}\right)^.5 \\
# \Rightarrow \ y = \sqrt{\frac{100b^2}{a^2+b^2}} \ \ Similarly, \ x= \sqrt{\frac{100a^2}{a^2+b^2}}, \ \ a=b=1 \\
# x=y \simeq 7.07 \  or \ 5 \sqrt{2}
# \end{equation*}
# </h2>
# <p><font face="Times New Roman" size="5">IV)
# </font></p>
# <br>
# <br>

# %%
plt.figure(figsize=(6,6))
plt.plot(x, ppf(x,1))
plt.plot(x2,ppf(x2,2))
plt.xlabel("Coconuts",fontsize="20")
plt.ylabel("Fish", fontsize="20")
plt.xlim(0,15)
plt.ylim(0,np.sqrt(199))
plt.margins(y=.1, x=.1)
plt.tight_layout()
plt.gcf()
plt.tick_params(labelsize="20")
plt.show()

# %%
Ax=1
x2=np.linspace(0.1,30, 1000)
x3 = np.linspace(0.1,30, 1000)
x4 = np.linspace(1,60, 30)
x5 = np.linspace(0.1, np.sqrt(199.99),800)
a=b=1

def indiff1(x3,ubar):
    return ubar-x

def indiff2(x4,ubar):
    return ubar-x

# %%
import warnings
warnings.filterwarnings('ignore')
plt.style.use("ggplot")
plt.figure(figsize=(6,6))
plt.plot(x, ppf(x,1), color="blue")
plt.plot(x2,ppf(x2,2),color="green")
plt.plot(x,indiff1(x,14.14))
plt.vlines(7.07,0,7.07, linestyles="dotted")
plt.hlines(7.07,0,7.07, linestyles="dotted")
plt.plot(x,indiff2(x5,17.32))
plt.vlines(11.547,0,5.77, linestyles="dotted")
plt.hlines(5.77,0,11.547, linestyles="dotted")
plt.xlabel("Coconuts",fontsize="20")
plt.ylabel("Fish", fontsize="20")
plt.xlim(0,20)
plt.ylim(0,np.sqrt(198))
plt.tight_layout()
plt.gcf()
plt.tick_params(labelsize="20")
plt.show()

# %% [markdown]
# <p><font face="Times New Roman" size="5">V)
# </font></p>
# <br>
# <br>
# <p><font size="4" face="Times New Roman">             Since Robinson's coconut productivity improved, he is now able to get the same amount of cocounts as he did before his productivity increased. Additionally, the labor hours saved from being able to get the same amount of coconuts in half the amount of time can be allotted to catching fish that he would not be able to catch had he not increased his productivity by getting more coconuts in a shorter time period. Thinking about this in terms of income and substitution effects, coconuts are now more relatively cheaper in labor hours than catching fish. As for the income effect, since Robinson has more income or in this case labor hours, he can now use the extra labor hours from his increased productivity to catch more fish. </font></p>
#     <br>
#      <p><font face="Times New Roman" size="5">VI)
# </font></p>
# <h2>
# \begin{equation*}
# \frac{x^2}{2}+\left(\ \frac{xb}{2a}\right)^2=100 \\
# \Rightarrow \ \frac{x^2}{2}+ \frac{x^2b^2}{4a^2}=100 \\
# \Rightarrow \ x^2 \left(\ \frac{2a^2+b^2}{4a^2}\right)=100 \\
# \Rightarrow  \ x^2 \frac{\left(\frac{2a^2+b^2}{4a^2}\right)}{\left(\frac{2a^2+b^2}{4a^2}\right)} = \frac{100}{\left(\frac{2a^2+b^2}{4a^2}\right)} \\
# \Rightarrow \ x^*= \sqrt{\frac{400a^2}{2a^2+b^2}}, \ Similarly: y^*= \sqrt{\frac{100b^2}{2a^2+b^2}} \\
# x=11.547, \ y=5.77
# \end{equation*}
# </h2>
#
#
# <p><font face="Times New Roman" size="5">VII)
# </font></p>
#
# <br>
# <font face="Times New Roman" size="3">Doubling both a and b would change the optimum solution. </font>

# %% [markdown]
# <p><font face="Times New Roman" size="5">5.
# </font></p>
# <br>
# <h2>
# \begin{equation*}
# \bullet U(x,y) \ \ \ \ MU_x=y, \ MU_y=x, \ MRS= \frac{y}{x} \\
# U(x,y)=xy=100\\
# \begin{array}{|c|c|c|c|}
# \hline
# x & 10& 20& 5 & 25 & 4\\ \hline
# y & 10 & 5 & 20 & 4 & 25\\ \hline
# \end{array} \\ \\ \ \\
# \end{equation*}
# </h2>

# %%
x = np.linspace(0.1,30,100) 
def util(x):
    return (100/x)
plt.figure(figsize=(6,6))
plt.style.use("ggplot")
plt.ylim(0,25)
plt.xlim(0,25)
plt.plot(x, util(x))
plt.xlabel("x", fontsize="20")
plt.ylabel("y", fontsize="20")
plt.tick_params(labelsize=20)
plt.show()

# %% [markdown]
# <h2>
# \begin{equation*}
# \bullet U(x,y)=x^2y^2 \ \ \  MU_x= 2xy^2, \ \ \ \ MU_y=2yx^2 \\
# \frac{MU_x}{MU_y}= \frac{2xy^2}{2yx^2} \ = \frac{y}{x} = MRS    \\
# \\ x^2y^2=100 \rightarrow (xy)^2=100 \rightarrow  ((xy)^2)^.5= \sqrt{100}   \\
# U(x,y)=xy=10 \\
# \begin{array}{|c|c|c|c|}
# \hline
# x & 5& 2& 1 & 10 \\ \hline
# y & 2 & 5 & 10 & 1 \\ \hline
# \end{array} \\ \\ \ \\
# \end{equation*}
# </h2>

# %%
x = np.linspace(0.1,10,100)
def uti(x):
    return (10/x)
plt.figure(figsize=(6,6))
plt.style.use("ggplot")
plt.plot(x,uti(x))
plt.xlabel("x", fontsize="20")
plt.ylabel("y", fontsize="20")
plt.xlim(0,10)
plt.ylim(0,10)
plt.tick_params(labelsize=20)
plt.show()

# %% [markdown]
# <h2>
# \begin{equation*}
# \bullet U(x,y)=ln(x)+ln(y)   \\
# e^{100}=e^{ln(xy)} \\
# \frac{e^{100}}{x}= \frac{xy}{x} \\
# y= \frac{e^{100}}{x}                    \\
# \\ \begin{array}{|c|c|c|c|}
# \hline
# x & 1& 2\\ \hline
# y & 2.69^{100} & 1.34*10^{43}\\ \hline
# \end{array} \\ \\ \ \\
# \end{equation*}
# </h2>

# %%
import math
x = np.linspace(1,30,500)
def nval(x):
    return np.exp(100)/x
plt.style.use("seaborn-deep")
plt.plot(x, nval(x), color="red")
plt.xlabel("x", fontsize="20")
plt.ylabel("y", fontsize="20")
plt.tick_params(labelsize=20)
plt.grid()
plt.show()
